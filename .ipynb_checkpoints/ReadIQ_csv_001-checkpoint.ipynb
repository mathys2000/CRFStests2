# %% [markdown]
# # ReadIQ_csv 001
#
# Read IQ samples from time-data.csv, recoded in CRFS Mission Manager

# %%
import numpy as np
import matplotlib.pyplot as plt
import myLTE as lte
import csv
import pandas as pd

# %%
# %matplotlib widget
fsz = (7,4)
fsz2 = (fsz[0], 1.2*fsz[1]/2.0)

# %%
# Read single IQ data record in
# IQ_080525a_csv_N1/time-data.csv
sigName = 'IQ_080525a_N1'
folder_in = 'IQ_080525a_csv_N1'
fname = 'time-data'
#-------------------------------------------------

full_fname = f'{folder_in}/{fname}'
IQdf = pd.read_csv(full_fname + '.csv', header=0)   # IQ dataframe
IQdf.head()
# Out:
#      id                      _repr  area   bandwidth  center_frequency  \
# 0  2923  05 Aug 2025, 16:04:48 UTC   NaN  10000000.0        15000000.0
#
#                              event_uuid  \
# 0  916fa202-6e88-452d-9aef-48a73eef3f0e
#
#                                                    i mission modulations  \
# 0  [-0.0000012368301,0.0000024350093,-0.000010938...   "WWV"          []
#
#           node                                                  q  \
# 0  rfeye300311  [0.00000699582,-0.000019016263,-0.000031036707...
#
#    sample_period                    timestamp
# 0   6.400000e-08  2025-08-05T16:04:48.212092Z

# %%
# List column names
col_list = IQdf.columns.tolist()
print(col_list)
# Out:
# ['id', '_repr', 'area', 'bandwidth', 'center_frequency', 'event_uuid', 'i', 'mission', 'modulations', 'node', 'q', 'sample_period', 'timestamp']

# %%
# Get sampling rate
Ts = IQdf.loc[0, 'sample_period']
Fs = int(np.round(1/Ts))   # sampling rate
print(Fs)
# Out:
# 15625000

# %%
# Get I and Q data strings
yIt_str = IQdf.loc[0, 'i']
yQt_str = IQdf.loc[0, 'q']
print(yIt_str[:60])
print(yQt_str[:60])
# Out:
# [-0.0000012368301,0.0000024350093,-0.000010938216,-0.0000206
# [0.00000699582,-0.000019016263,-0.000031036707,-0.0000035558
